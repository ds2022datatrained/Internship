# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %% [markdown]
# Answer of Question No.-1

# %%
# Downloaded the web driver and uploaded in current Jupyter Directory
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
# Opening Naukri.com page via coding
driver.get("https://www.naukri.com/")

# %%
Designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
Designation.send_keys("Data Analyst")

# %%
Location=driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input")
Location.send_keys("Banglore")

# %%
Search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
Search.click()

# %%
Job_Title=[]
Job_Location=[]
Company_Name=[]
Experience_Required=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    Job_Title.append(title)

# %%
Job_Title
# Out:
# ['Data Analyst',
#  'Tech Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Celonis & Salesforce Data Analyst',
#  'Celonis & Salesforce Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst']

# %%
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    Job_Location.append(location)

# %%
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    Company_Name.append(company)

# %%
experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[0:10]:
    experience=i.text
    Experience_Required.append(experience)

# %%
print(len(Job_Title),len(Job_Location),len(Company_Name),len(Experience_Required))
# Out:
# 10 10 10 10

# %%
Job_Data_Analyst=pd.DataFrame({"Job Designation":Job_Title,"Location":Job_Location,"Company Name":Company_Name,"Experience Required":Experience_Required})

# %%
Job_Data_Analyst
# Out:
#                      Job Designation  \
# 0                       Data Analyst
# 1                  Tech Data Analyst
# 2                       Data Analyst
# 3                       Data Analyst
# 4  Celonis & Salesforce Data Analyst
# 5  Celonis & Salesforce Data Analyst
# 6                       Data Analyst
# 7                       Data Analyst
# 8                       Data Analyst
# 9                       Data Analyst
#
#                                             Location  \
# 0                                Bangalore/Bengaluru
# 1  Hybrid - Gurgaon/ Gurugram, Haryana, Bangalore...
# 2                    Bangalore/ Bengaluru, Karnataka
# 3                                Bangalore/Bengaluru
# 4                       Chennai, Bangalore/Bengaluru
# 5                                Bangalore/Bengaluru
# 6                       Hybrid - Bangalore/Bengaluru
# 7          Hybrid - Bangalore/Bengaluru, Delhi / NCR
# 8          Hybrid - Bangalore/Bengaluru, Delhi / NCR
# ...

# %% [markdown]
# Answer of Question No.-2

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME, 'suggestor-input ')
designation.send_keys("Data Scientist")

# %%
location=driver.find_element(By.XPATH,'/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input')
location.send_keys("Banglore")

# %%
search=driver.find_element(By.CLASS_NAME,'qsbSubmit')
search.click()

# %%
dstitle=[]
dslocation=[]
dscompany_name=[]

# %%
dsTitle=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in dsTitle[0:10]:
    Title=i.text
    dstitle.append(Title)

# %%
dsLocation=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in dsLocation[0:10]:
    Loc=i.text
    dslocation.append(Loc)

# %%
dscomp_name=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in dscomp_name[0:10]:
    comp_name=i.text
    dscompany_name.append(comp_name)

# %%
print(len(dstitle),len(dslocation),len(dscompany_name))
# Out:
# 10 10 10

# %%
Data_Scientist_Jobs=pd.DataFrame({"Job Designation":dstitle,"Job Location":dslocation,"Company Name":dscompany_name})

# %%
Data_Scientist_Jobs
# Out:
#                                      Job Designation  \
# 0  Permanent Opportunity - Data Scientist(Snaplog...
# 1                   Analystics & Modeling Specialist
# 2                    Machine Learning (AI) Architect
# 3                               Staff Data Scientist
# 4                                     Data Scientist
# 5                          Hiring For Data Scientist
# 6                                     Data Scientist
# 7            Director/Senior Director - Data Science
# 8              Manager/Senior Manager - Data Science
# 9                                     Data Scientist
#
#                                         Job Location  \
# 0  Hybrid - Kolkata, Hyderabad/Secunderabad, Pune...
# 1  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...
# 2  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# 3                                Bangalore/Bengaluru
# 4                    Bangalore/ Bengaluru, Karnataka
# 5  Hybrid - Hyderabad/ Secunderabad, Telangana, C...
# ...

# %% [markdown]
# Answer of Question No.-3

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.naukri.com/")

# %%
dsjob=driver.find_element(By.CLASS_NAME,'suggestor-input ')
dsjob.send_keys("Data Scientist")

# %%
dssearch=driver.find_element(By.CLASS_NAME,'qsbSubmit')
dssearch.click()

# %%
search_loc=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[5]/div[2]/div[2]/label/p/span[1]')
search_loc.click()

# %%
search_salary=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[6]/div[2]/div[2]/label/p/span[1]')
search_salary.click()

# %%
J_title=[]
J_location=[]
Comp_name=[]
Experience_req=[]

# %%
jt=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in jt[0:10]:
    t=i.text
    J_title.append(t)

# %%
jl=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in jl[0:10]:
    l=i.text
    J_location.append(l)

# %%
cn=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in cn[0:10]:
    co=i.text
    Comp_name.append(co)

# %%
er=driver.find_elements(By.XPATH,'//div[@class="ellipsis job-description"]')
for i in er[0:10]:
    exp=i.text
    Experience_req.append(exp)

# %%
ds_jobs_ncr=pd.DataFrame({"Designation":J_title,"Location":J_location,"Company Name":Comp_name,"Experience Required":Experience_req})

# %%
ds_jobs_ncr
# Out:
#               Designation                                           Location  \
# 0   Junior Data Scientist  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# 1          Data Scientist              Gurgaon/Gurugram, Bangalore/Bengaluru
# 2          Data Scientist                                              Noida
# 3          Data Scientist  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# 4   Python and ML Trainer  Hyderabad/Secunderabad, New Delhi, Pune, Gurga...
# 5          Data Scientist                                        Delhi / NCR
# 6                  Intern                                   Gurgaon/Gurugram
# 7  Lead Assistant Manager                                   Gurgaon/Gurugram
# 8          Data Scientist                                              Noida
# 9   Junior Data Scientist    Gurgaon/Gurugram, United States (USA), Bulgaria
#
#                       Company Name  \
# 0                         Analytos
# 1                        Blackbuck
# ...

# %% [markdown]
# Answer of Question No.-4

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.flipkart.com/")

# %%
sg=driver.find_element(By.CLASS_NAME,'_3704LK')
sg.send_keys("Sunglasses")

# %%
icon1=driver.find_element(By.XPATH,'/html/body/div[2]/div/div/button')
icon1.click()

# %%
icon=driver.find_element(By.CLASS_NAME,'L0Z3Pu')
icon.click()

# %%
Brand_Name=[]
Product_Des=[]
Price=[]

# %%
start=0
end=3
for page in range(start,end):
    brand=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand[0:100]:
        b=i.text
        Brand_Name.append(b)
    n_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    n_button.click()
    time.sleep(3)

# %%
print(len(Brand_Name))
# Out:
# 120

# %%
start=0
end=3
for page in range(start,end):
    prod_des=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in prod_des[0:100]:
        p=i.text
        Product_Des.append(p)
    n_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    n_button.click()
    time.sleep(3)

# %%
start=0
end=3
for page in range(start,end):
    pri=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in pri[0:100]:
        pr=i.text
        Price.append(pr)
    n_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    n_button.click()
    time.sleep(3)

# %%
Price_Off=[]

# %%
start=0
end=3
for page in range(start,end):
    of=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
    for i in of[0:100]:
        off=i.text
        Price_Off.append(off)
    n_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    n_button.click()
    time.sleep(3)

# %%
print(len(Brand_Name),len(Product_Des),len(Price),len(Price_Off))
# Out:
# 120 118 120 120

# %%
brand_name=Brand_Name[0:100]

# %%
product_des=Product_Des[0:100]

# %%
price=Price[0:100]

# %%
price_off=Price_Off[0:100]

# %%
print(len(brand_name),len(product_des),len(price),len(price_off))
# Out:
# 100 100 100 100

# %%
Sunglasses_details=pd.DataFrame({"Brands":brand_name,'Product Description':product_des,"Price":price,"Price Off":price_off})

# %%
Sunglasses_details
# Out:
#            Brands                                Product Description Price  \
# 0          Dervin  UV Protection Retro Square Sunglasses (Free Size)  ₹234
# 1       ROYAL SON  Others Cat-eye, Retro Square, Wayfarer Sunglas...  ₹471
# 2        Fastrack  by Lenskart Polarized, UV Protection Cat-eye S...  ₹499
# 3            BKGE  by Lenskart Polarized, UV Protection Wayfarer ...  ₹149
# 4       Elligator  Polarized, UV Protection, Riding Glasses Wayfa...  ₹179
# ..            ...                                                ...   ...
# 95  VINCENT CHASE  Polarized, Riding Glasses Sports, Wrap-around ...  ₹899
# 96      Elligator      UV Protection Wayfarer Sunglasses (Free Size)  ₹192
# 97       Fastrack                Others Retro Square Sunglasses (52)  ₹569
# 98       Fastrack             UV Protection Wayfarer Sunglasses (53)  ₹569
# 99         AISLIN  UV Protection, Night Vision, Riding Glasses Av...  ₹636
#
#    Price Off
# 0    80% off
# 1    87% off
# 2    80% off
# ...

# %% [markdown]
# Answer of Question No.-5

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market")

# %%
Rating=[]

# %%
start=0
end=10
for page in range(start,end):
    rt=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in rt:
        r=i.text
        Rating.append(r)
    n_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    n_button.click()
    time.sleep(3)

# %%
Review=[]
start=0
end=10
for page in range(start,end):
    rv=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
    for i in rv:
        rev=i.text
        Review.append(rev)
    n_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    n_button.click()
    time.sleep(3)

# %%
Full_Review=[]
start=0
end=10
for page in range(start,end):
    frv=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for i in frv:
        frev=i.text
        Full_Review.append(frev)
    n_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    n_button.click()
    time.sleep(3)

# %%
print(len(Rating),len(Review),len(Full_Review))
# Out:
# 100 100 100

# %%
rating=Rating[0:100]

# %%
print(len(rating),len(Review),len(Full_Review))
# Out:
# 100 100 100

# %%
iPhone_Rating=pd.DataFrame({"Rating":rating,"Review":Review,"Full Review":Full_Review})

# %%
iPhone_Rating
# Out:
#    Rating               Review  \
# 0       5       Simply awesome
# 1       5     Perfect product!
# 2       5  Best in the market!
# 3       4      Value-for-money
# 4       5   Highly recommended
# ..    ...                  ...
# 95      5     Perfect product!
# 96      5   Highly recommended
# 97      5   Highly recommended
# 98      4      Value-for-money
# 99      5     Perfect product!
#
#                                           Full Review
# 0   Really satisfied with the Product I received.....
# 1   Amazing phone with great cameras and better ba...
# 2   Great iPhone very snappy experience as apple k...
# 3   I'm Really happy with the product\nDelivery wa...
# 4   It's my first time to use iOS phone and I am l...
# ..                                                ...
# 95  Value for money❤️❤️\nIts awesome mobile phone ...
# 96  iphone 11 is a very good phone to buy only if ...
# 97  Amazing camera quality as expected, battery al...
# ...

# %% [markdown]
# Answer of Question No.-6

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.flipkart.com/")

# %%
s_brand=driver.find_element(By.CLASS_NAME,"_3704LK")
s_brand.send_keys("sneakers")

# %%
s_close=driver.find_element(By.XPATH,'/html/body/div[2]/div/div/button')
s_close.click()

# %%
s_search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
s_search.click()

# %%
sneaker_brand=[]
start=0
end=3
for page in range(start,end):
    sn_brand=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in sn_brand:
        snb=i.text
        sneaker_brand.append(snb)
    n_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    n_button.click()
    time.sleep(3)

# %%
print(len(sneaker_brand))
# Out:
# 120

# %%
sneaker_prod_des=[]
start=0
end=3
for page in range(start,end):
    sn_p_d=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in sn_p_d:
        snpd=i.text
        sneaker_prod_des.append(snpd)
    n_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    n_button.click()
    time.sleep(3)

# %%
sneaker_price=[]
start=0
end=3
for page in range(start,end):
    sn_price=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in sn_price:
        snpr=i.text
        sneaker_price.append(snpr)
    n_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    n_button.click()
    time.sleep(3)

# %%
sneaker_price_off=[]
start=0
end=3
for page in range(start,end):
    sn_price_off=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
    for i in sn_price_off:
        snpro=i.text
        sneaker_price_off.append(snpro)
    n_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    n_button.click()
    time.sleep(3)

# %%
print(len(sneaker_brand),len(sneaker_prod_des),len(sneaker_price),len(sneaker_price_off))
# Out:
# 120 114 120 120

# %%
Sneaker_Brand=sneaker_brand[0:100]

# %%
Sneaker_prod_des=sneaker_prod_des[0:100]

# %%
Sneaker_price=sneaker_price[0:100]

# %%
Sneaker_price_off=sneaker_price_off[0:100]

# %%
print(len(Sneaker_Brand),len(Sneaker_prod_des),len(Sneaker_price),len(Sneaker_price_off))
# Out:
# 100 100 100 100

# %%
Sneaker_details=pd.DataFrame({"Sneaker Brand":Sneaker_Brand,"Product Description":Sneaker_prod_des,"Price":Sneaker_price,"Price Off":Sneaker_price_off})

# %%
Sneaker_details
# Out:
#             Sneaker Brand                                Product Description  \
# 0                     SFR  Styles Men's Fashion Outdoor Trend High Top Sp...
# 1                RapidBox  Premium White Casual Shoes Sneakers For Men Sn...
# 2                  Labbin                                   Sneakers For Men
# 3                    PUMA  Men's W-05 Casual White Sneaker Shoes With Wat...
# 4                    PUMA  Latest Exclusive Affordable Collection of Tren...
# ..                    ...                                                ...
# 95  HRX by Hrithik Roshan  Men Combo Pack of 2 Casual & Sneaker Shoes (Lo...
# 96               Magnolia  Stylish & Trending Outdoor Walking Comfortable...
# 97                AIRBELL                      Harrow Wns Sneakers For Women
# 98                   PUMA    Men Retro Basket Ball Sneakers Sneakers For Men
# 99  HRX by Hrithik Roshan                Men White Sneakers Sneakers For Men
#
#      Price Price Off
# 0     ₹429   45% off
# ...

# %% [markdown]
# Answer of Question No.-7

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.amazon.in/")

# %%
laptop=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
laptop.send_keys("Laptop")

# %%
l_search=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
l_search.click()

# %%
i7_search=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[5]/ul[6]/span[11]/li/span/a/span')
i7_search.click()

# %%
laptop_title=[]
start=0
end=1
for page in range(start,end):
    l_title=driver.find_elements(By.XPATH,'//span[@class="a-size-medium a-color-base a-text-normal"]')
    for i in l_title[0:10]:
        lt=i.text
        laptop_title.append(lt)
    n_button=driver.find_element(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
    n_button.click()
    time.sleep(3)

# %%
print(len(laptop_title))
# Out:
# 10

# %%
laptop_rating=[]
start=0
end=1
for page in range(start,end):
    l_rating=driver.find_elements(By.XPATH,'//span[@class="a-size-base s-underline-text"]')
    for i in l_rating[0:10]:
        lr=i.text
        laptop_rating.append(lr)
    n_button=driver.find_element(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
    n_button.click()
    time.sleep(3)

# %%
laptop_price=[]
start=0
end=1
for page in range(start,end):
    l_price=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
    for i in l_price[0:10]:
        lp=i.text
        laptop_price.append(lp)
    n_button=driver.find_element(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
    n_button.click()
    time.sleep(3)

# %%
print(len(laptop_title),len(laptop_rating),len(laptop_price))
# Out:
# 10 10 10

# %%
Laptop_i7_Top10=pd.DataFrame({"Title":laptop_title,"Rating":laptop_rating,"Price":laptop_price})

# %%
Laptop_i7_Top10
# Out:
#                                                Title Rating     Price
# 0  HP Laptop 15s, 12th Gen Intel Core i7-1255U, 1...      4    23,290
# 1  ASUS TUF Gaming F15 (2023) 90WHr Battery, Inte...     21    34,500
# 2  Acer Predator Helios Neo 16 Gaming Laptop 13th...    361    93,990
# 3  MSI Thin GF63, Intel 12th Gen. i7-12650H, 40CM...      9    23,349
# 4  HP Envy x360 12th Gen Intel Core i7-13.3 inch(...    230    89,999
# 5  Lenovo ThinkPad E14 Intel Core i7 12th Gen 14"...     18    23,239
# 6  Lenovo IdeaPad Slim 5 Intel Core i7 12th Gen 1...     24    92,889
# 7  Samsung Galaxy Book2 360 Intel 12th Gen i7 Evo...     11    21,698
# 8  ASUS TUF Gaming F15 (2022), 15.6"(39.62 cms) F...     38    37,487
# 9  Acer Predator Helios Neo 16 Gaming Laptop 13th...     19  1,04,592

# %% [markdown]
# Answer of Question No.-8

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.azquotes.com/")

# %%
top_quotes=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a')
top_quotes.click()

# %%
Quotes=[]
start=0
end=10
for page in range(start,end):
    qts=driver.find_elements(By.CLASS_NAME,'title')
    for i in qts:
        qt=i.text
        Quotes.append(qt)
    n_button=driver.find_element(By.CLASS_NAME,'next')
    n_button.click()
    time.sleep(3)
    f_button=driver.find_element(By.CLASS_NAME,"first")
    f_button.click()

# %%
Quotes
# Out:
# ['Authors:',
#  'The essence of strategy is choosing what not to do.',
#  'One cannot and must not try to erase the past merely because it does not fit the present.',
#  'Patriotism means to stand by the country. It does not mean to stand by the president.',
#  'Death is something inevitable. When a man has done what he considers to be his duty to his people and his country, he can rest in peace. I believe I have made that effort and that is, therefore, why I will sleep for the eternity.',
#  'You have to love a nation that celebrates its independence every July 4, not with a parade of guns, tanks, and soldiers who file by the White House in a show of strength and muscle, but with family picnics where kids throw Frisbees, the potato salad gets iffy, and the flies die from happiness. You may think you have overeaten, but it is patriotism.',
# ...

# %%
print(len(Quotes))
# Out:
# 1040

# %%
quotes=Quotes[1:1001]

# %%
quotes
# Out:
# ['The essence of strategy is choosing what not to do.',
#  'One cannot and must not try to erase the past merely because it does not fit the present.',
#  'Patriotism means to stand by the country. It does not mean to stand by the president.',
#  'Death is something inevitable. When a man has done what he considers to be his duty to his people and his country, he can rest in peace. I believe I have made that effort and that is, therefore, why I will sleep for the eternity.',
#  'You have to love a nation that celebrates its independence every July 4, not with a parade of guns, tanks, and soldiers who file by the White House in a show of strength and muscle, but with family picnics where kids throw Frisbees, the potato salad gets iffy, and the flies die from happiness. You may think you have overeaten, but it is patriotism.',
# ...

# %%
print(len(quotes))
# Out:
# 1000

# %%
Author=[]
start=0
end=10
for page in range(start,end):
    aut=driver.find_elements(By.XPATH,'//DIV[@class="author"]')
    for i in aut:
        at=i.text
        Author.append(at)
    n_button=driver.find_element(By.CLASS_NAME,'next')
    n_button.click()
    time.sleep(3)
    f_button=driver.find_element(By.CLASS_NAME,"first")
    f_button.click()

# %%
Author
# Out:
# ['Michael Porter',
#  'Golda Meir',
#  'Theodore Roosevelt',
#  'Nelson Mandela',
#  'Erma Bombeck',
#  'John Wooden',
#  'Albert Einstein',
#  'Frank Zappa',
#  'William Faulkner',
#  'Will Rogers',
#  'Jimmy Carter',
#  'Albert Einstein',
#  'Abraham Lincoln',
#  'Steven Weinberg',
#  'Franklin D. Roosevelt',
#  'Albert Einstein',
#  'Maya Angelou',
#  'Mark Twain',
#  'Theodore Roosevelt',
#  'Michael Jackson',
#  'Martin Luther King, Jr.',
#  'C. S. Lewis',
#  'Theodore Roosevelt',
#  'Mark Twain',
#  'Abraham Lincoln',
#  'Ruth Graham',
#  'C. S. Lewis',
#  'Groucho Marx',
#  'John Lennon',
#  'Barbara Bush',
#  'Albert Einstein',
#  'Francis Chan',
#  'Henry Ford',
#  'Victor Hugo',
#  'Abu Bakr',
#  'Zig Ziglar',
#  'Winston Churchill',
#  'Zig Ziglar',
#  'John F. Kennedy',
#  'Dwight D. Eisenhower',
#  'Winston Churchill',
#  'Albert Einstein',
#  'Willie Nelson',
#  'Johnny Cash',
#  'Marie Curie',
#  'Maya Angelou',
#  'Amy Bloom',
#  'Zig Ziglar',
#  'John Lennon',
# ...

# %%
print(len(Author))
# Out:
# 1000

# %%
Quote_Type=[]
start=0
end=10
for page in range(start,end):
    q_ty=driver.find_elements(By.CLASS_NAME,'tags')
    for i in q_ty:
        qty=i.text
        Quote_Type.append(qty)
    n_button=driver.find_element(By.CLASS_NAME,'next')
    n_button.click()
    time.sleep(3)
    f_button=driver.find_element(By.CLASS_NAME,"first")
    f_button.click()

# %%
print(len(Quote_Type))
# Out:
# 1000

# %%
Quote_Type
# Out:
# ['Essence, Deep Thought, Transcendentalism',
#  'Inspiration, Past, Trying',
#  'Country, Peace, War',
#  'Inspirational, Motivational, Death',
#  '4th Of July, Food, Patriotic',
#  'Inspirational, Success, Basketball',
#  'Strong, Revenge, Intelligent',
#  'Inspirational, Teacher, Religious',
#  'Truth, Honesty, Lying',
#  'Funny, Reading, Learning',
#  'Strong, Thoughtful, Compassion',
#  'Love, Funny, Life',
#  'Freedom, Men, Democracies Have',
#  'God, Religious, Atheist',
#  'Respect, Kindness, Character',
#  'Inspirational, Motivational, Change',
#  'Inspirational, Life, Inspiring',
#  'Love, Inspirational, Life',
#  'Inspiring, Country, 4th Of July',
#  'Inspirational, Dream, Hate',
#  'Love, Inspirational, Life',
#  'Forgiveness, God, Christian',
#  'Country, Men, Squares',
#  'Inspirational, Relationship, Positive',
#  'Inspirational, Motivational, Positive',
#  'Love, Friendship, Relationship',
#  'Faith, God, Christian',
#  'Art, Freedom, Political Will',
# ...

# %%
Quotes_1000=pd.DataFrame({"Quotes":quotes,"Author":Author,"Type of Quotes":Quote_Type})

# %%
Quotes_1000
# Out:
#                                                 Quotes                Author  \
# 0    The essence of strategy is choosing what not t...        Michael Porter
# 1    One cannot and must not try to erase the past ...            Golda Meir
# 2    Patriotism means to stand by the country. It d...    Theodore Roosevelt
# 3    Death is something inevitable. When a man has ...        Nelson Mandela
# 4    You have to love a nation that celebrates its ...          Erma Bombeck
# ..                                                 ...                   ...
# 995  Sports for me is when a guy walks off the cour...    Hunter S. Thompson
# 996  Expect the best. Prepare for the worst. Capita...       Corrie Ten Boom
# 997  I became insane, with long intervals of horrib...            Dalai Lama
# 998        Failure is a detour, not a dead-end street.         Mother Teresa
# 999  I am not a product of my circumstances. I am a...  Norman Vincent Peale
#
# ...

# %% [markdown]
# Answer of Question No.-9

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.jagranjosh.com/")

# %%
gk=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div/div[1]/div/div[5]/div/div[1]/header/div[3]/ul/li[3]/a")
gk.click()

# %%
pm=driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a')
pm.click()

# %%
PM_Name=[]
name=driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[2]/p')
for i in name:
    n=i.text
    PM_Name.append(n)

# %%
PM_Name
# Out:
# ['Jawahar Lal Nehru',
#  'Gulzarilal Nanda (Acting)',
#  'Lal Bahadur Shastri',
#  'Gulzari Lal Nanda  (Acting)',
#  'Indira Gandhi',
#  'Morarji Desai',
#  'Charan Singh',
#  'Indira Gandhi',
#  'Rajiv Gandhi',
#  'V. P. Singh',
#  'Chandra Shekhar',
#  'P. V. Narasimha Rao',
#  'Atal Bihari Vajpayee',
#  'H. D. Deve Gowda',
#  'Inder Kumar Gujral',
#  'Atal Bihari Vajpayee',
#  'Manmohan Singh',
#  'Narendra Modi',
#  'Narendra Modi']

# %%
Born_Dead=[]
b_d=driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[3]/p')
for i in b_d:
    bd=i.text
    Born_Dead.append(bd)

# %%
Born_Dead
# Out:
# ['(1889–1964)',
#  '(1898-1998)',
#  '(1904–1966)',
#  '(1898-1998)',
#  '(1917–1984)',
#  '(1896–1995)',
#  '(1902–1987)',
#  '(1917–1984)',
#  '(1944–1991)',
#  '(1931–2008)',
#  '(1927–2007)',
#  '(1921–2004)',
#  '(1924- 2018)',
#  '(born 1933)',
#  '(1919–2012)',
#  '(1924-2018)',
#  '(born 1932)',
#  '(born 1950)',
#  '(born 1950)']

# %%
Term_of_Office=[]
tof=driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[4]/p[1]')
for i in tof:
    tf=i.text
    Term_of_Office.append(tf)

# %%
Term_of_Office
# Out:
# ['15 August 1947 to 27 May 1964',
#  '27 May 1964 to 9 June 1964,',
#  '9 June 1964 to 11 January 1966',
#  '11 January 1966 to 24 January 1966',
#  '24 January 1966 to 24 March 1977',
#  '24 March 1977 to  28 July 1979 ',
#  '28 July 1979 to 14 January 1980',
#  '14 January 1980 to 31 October 1984',
#  '31 October 1984 to 2 December 1989',
#  '2 December 1989 to 10 November 1990',
#  '10 November 1990 to 21 June 1991',
#  '21 June 1991 to 16 May 1996',
#  '16 May 1996 to 1 June 1996',
#  '1 June 1996 to 21 April 1997',
#  '21 April 1997 to 19 March 1998 ',
#  '19 March 1998 to 22 May 2004 ',
#  '22 May 2004 to 26 May 2014   ',
#  '26 May 2014 - 2019',
#  '30 May 2019- Incumbent']

# %%
Remarks=[]
rem=driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[5]/p')
for i in rem:
    rm=i.text
    Remarks.append(rm)

# %%
Remarks
# Out:
# ['The first prime minister of India and the longest-serving PM of India, the first to die in office.',
#  'First acting PM of India',
#  "He has given the slogan of 'Jai Jawan Jai Kisan' during the Indo-Pak war of 1965",
#  '-',
#  'First female Prime Minister of India',
#  'Oldest to become PM (81 years old) and first to resign from office',
#  'Only PM who did not face the Parliament',
#  'The first lady who served as PM for the second term',
#  'Youngest to become PM (40 years old)',
#  'First PM to step down after a vote of no confidence',
#  'He belongs to  Samajwadi Janata Party',
#  'First PM from South India',
#  'PM for shortest tenure',
#  'He belongs to  Janata Dal',
#  '------',
#  ' The first non-congress PM who completed a full term as PM',
#  ' First Sikh PM',
#  '4th Prime Minister of India who served two consecutive tenures',
#  'First non-congress PM with two consecutive tenures']

# %%
print(len(PM_Name),len(Born_Dead),len(Term_of_Office),len(Remarks))
# Out:
# 19 19 19 19

# %%
PM_of_India=pd.DataFrame({"PM Name":PM_Name,"Born Dead":Born_Dead,"Term of Office":Term_of_Office,"Remarks":Remarks})

# %%
PM_of_India
# Out:
#                         PM Name     Born Dead  \
# 0             Jawahar Lal Nehru   (1889–1964)
# 1     Gulzarilal Nanda (Acting)   (1898-1998)
# 2           Lal Bahadur Shastri   (1904–1966)
# 3   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4                 Indira Gandhi   (1917–1984)
# 5                 Morarji Desai   (1896–1995)
# 6                  Charan Singh   (1902–1987)
# 7                 Indira Gandhi   (1917–1984)
# 8                  Rajiv Gandhi   (1944–1991)
# 9                   V. P. Singh   (1931–2008)
# 10              Chandra Shekhar   (1927–2007)
# 11          P. V. Narasimha Rao   (1921–2004)
# 12         Atal Bihari Vajpayee  (1924- 2018)
# 13             H. D. Deve Gowda   (born 1933)
# 14           Inder Kumar Gujral   (1919–2012)
# 15         Atal Bihari Vajpayee   (1924-2018)
# 16               Manmohan Singh   (born 1932)
# 17                Narendra Modi   (born 1950)
# 18                Narendra Modi   (born 1950)
#
# ...

# %% [markdown]
# Answer of Question No.-10

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.motor1.com/")

# %%
car=driver.find_element(By.XPATH,'//input[@class="m1-search-panel-input m1-search-form-text"]')
car.send_keys("50 most expensive cars")

# %%
car_search=driver.find_element(By.XPATH,'//button[@class="m1-search-panel-button m1-search-form-button-animate icon-search-svg"]')
car_search.click()

# %%
exp_car=driver.find_element(By.XPATH,'/html/body/div[3]/div[9]/div/div[1]/div/div/div[2]/div/div[1]/h3/a')
exp_car.click()

# %%
car_brand=[]
c_brand=driver.find_elements(By.CLASS_NAME,'subheader')
for i in c_brand:
    cb=i.text
    car_brand.append(cb)

# %%
print(len(car_brand))
# Out:
# 51

# %%
car_brand
# Out:
# ['De Tomaso P72',
#  'Ferrari LaFerrari',
#  'Pagani Huayra',
#  'McLaren Elva',
#  'Czinger 21C',
#  'Ferrari Monza',
#  'Gordon Murray T.33',
#  'Koenigsegg Gemera',
#  'Zenvo TSR-S',
#  'Hennessey Venom F5',
#  'Bentley Bacalar',
#  'Hispano Suiza Carmen Boulogne',
#  'Bentley Mulliner Batur',
#  'Deus Vayanne',
#  'SSC Tuatara',
#  'Lotus Evija',
#  'Aston Martin Vulcan',
#  'Delage D12',
#  'McLaren Speedtail',
#  'Rimac Nevera',
#  'Pagani Utopia',
#  'Pininfarina Battista',
#  'Ferrari FXX K Evo',
#  'Gordon Murray T.50',
#  'Lamborghini Countach',
#  'Mercedes-AMG Project One',
#  'Aston Martin Victor',
#  'Hennessey Venom F5 Roadster',
#  'Koenigsegg Jesko',
#  'Aston Martin Valkyrie',
#  'W Motors Lykan Hypersport',
#  'McLaren Solus',
#  'Pagani Huayra Roadster BC',
#  'Bugatti Chiron Pur Sport',
#  'Lamborghini Sian',
#  'Koenigsegg CC850',
#  'Bugatti Chiron Super Sport 300+',
#  'Lamborghini Veneno',
#  'Bugatti Bolide',
#  'Bugatti Mistral',
#  'Pagani Huayra Imola',
# ...

# %%
Car_brand=car_brand[0:50]

# %%
print(len(Car_brand))
# Out:
# 50

# %%
Car_brand
# Out:
# ['De Tomaso P72',
#  'Ferrari LaFerrari',
#  'Pagani Huayra',
#  'McLaren Elva',
#  'Czinger 21C',
#  'Ferrari Monza',
#  'Gordon Murray T.33',
#  'Koenigsegg Gemera',
#  'Zenvo TSR-S',
#  'Hennessey Venom F5',
#  'Bentley Bacalar',
#  'Hispano Suiza Carmen Boulogne',
#  'Bentley Mulliner Batur',
#  'Deus Vayanne',
#  'SSC Tuatara',
#  'Lotus Evija',
#  'Aston Martin Vulcan',
#  'Delage D12',
#  'McLaren Speedtail',
#  'Rimac Nevera',
#  'Pagani Utopia',
#  'Pininfarina Battista',
#  'Ferrari FXX K Evo',
#  'Gordon Murray T.50',
#  'Lamborghini Countach',
#  'Mercedes-AMG Project One',
#  'Aston Martin Victor',
#  'Hennessey Venom F5 Roadster',
#  'Koenigsegg Jesko',
#  'Aston Martin Valkyrie',
#  'W Motors Lykan Hypersport',
#  'McLaren Solus',
#  'Pagani Huayra Roadster BC',
#  'Bugatti Chiron Pur Sport',
#  'Lamborghini Sian',
#  'Koenigsegg CC850',
#  'Bugatti Chiron Super Sport 300+',
#  'Lamborghini Veneno',
#  'Bugatti Bolide',
#  'Bugatti Mistral',
#  'Pagani Huayra Imola',
# ...

# %%
Expensive_Cars=pd.DataFrame({"Names of 50 Most Expensive Cars in the World":Car_brand})

# %%
Expensive_Cars
# Out:
#    Names of 50 Most Expensive Cars in the World
# 0                                 De Tomaso P72
# 1                             Ferrari LaFerrari
# 2                                 Pagani Huayra
# 3                                  McLaren Elva
# 4                                   Czinger 21C
# 5                                 Ferrari Monza
# 6                            Gordon Murray T.33
# 7                             Koenigsegg Gemera
# 8                                   Zenvo TSR-S
# 9                            Hennessey Venom F5
# 10                              Bentley Bacalar
# 11                Hispano Suiza Carmen Boulogne
# 12                       Bentley Mulliner Batur
# 13                                 Deus Vayanne
# 14                                  SSC Tuatara
# 15                                  Lotus Evija
# 16                          Aston Martin Vulcan
# 17                                   Delage D12
# 18                            McLaren Speedtail
# ...
